# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# read in sample drought data
data = pd.read_csv('resources/test_spi_date.csv')
data
# Out:
#         Unnamed: 0   lat   lon        time     spi12
# 0              745 -55.5 -70.5  2012-01-16 -1.013668
# 1              746 -55.5 -70.5  2012-02-15 -1.142956
# 2              747 -55.5 -70.5  2012-03-16 -0.407607
# 3              748 -55.5 -70.5  2012-04-16 -0.726904
# 4              749 -55.5 -70.5  2012-05-16 -0.798656
# ...            ...   ...   ...         ...       ...
# 206317    13015466  83.5 -25.5  2012-08-16 -0.060361
# 206318    13015467  83.5 -25.5  2012-09-16 -0.055499
# 206319    13015468  83.5 -25.5  2012-10-16 -0.056157
# 206320    13015469  83.5 -25.5  2012-11-16 -0.056157
# 206321    13015470  83.5 -25.5  2012-12-16 -0.055763
#
# [206322 rows x 5 columns]

# %%
# drop nuisance column
data = data.drop(['Unnamed: 0'], axis=1)

# %%
data.dtypes
# Out:
# lat      float64
# lon      float64
# time      object
# spi12    float64
# dtype: object

# %%
# convert lat, lon from float to string
data.lat = [str(x) for x in data.lat]
data.lon = [str(x) for x in data.lon]

# %%
# use concat method to create unique lat, lon string pairing
data['coor1'] = data['lat'].str.cat(data['lon'], sep=' ')

# use numpy .values method to create lat, lon pairing as a list
data['coor2'] = data[['lat','lon']].values.tolist()

# %%
data
# Out:
#           lat    lon        time     spi12        coor1           coor2
# 0       -55.5  -70.5  2012-01-16 -1.013668  -55.5 -70.5  [-55.5, -70.5]
# 1       -55.5  -70.5  2012-02-15 -1.142956  -55.5 -70.5  [-55.5, -70.5]
# 2       -55.5  -70.5  2012-03-16 -0.407607  -55.5 -70.5  [-55.5, -70.5]
# 3       -55.5  -70.5  2012-04-16 -0.726904  -55.5 -70.5  [-55.5, -70.5]
# 4       -55.5  -70.5  2012-05-16 -0.798656  -55.5 -70.5  [-55.5, -70.5]
# ...       ...    ...         ...       ...          ...             ...
# 206317   83.5  -25.5  2012-08-16 -0.060361   83.5 -25.5   [83.5, -25.5]
# 206318   83.5  -25.5  2012-09-16 -0.055499   83.5 -25.5   [83.5, -25.5]
# 206319   83.5  -25.5  2012-10-16 -0.056157   83.5 -25.5   [83.5, -25.5]
# 206320   83.5  -25.5  2012-11-16 -0.056157   83.5 -25.5   [83.5, -25.5]
# 206321   83.5  -25.5  2012-12-16 -0.055763   83.5 -25.5   [83.5, -25.5]
#
# [206322 rows x 6 columns]

# %%
# create list of coordinates
coordinates = data.coor1.unique().tolist()

# create lists for lat and lng combinations
lats = [float(x.split()[0]) for x in coordinates]
lngs = [float(x.split()[1]) for x in coordinates]

# zip lat and lng together
lat_lngs = zip(lats, lngs)

# %%
len(coordinates)
# Out:
# 17194

# %%
# lists for holding lat, long and cities
cities = []
new_lat_lng = []

# identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # if the city is unique, then add it to the cities list
    if city not in cities:
        new_lat_lng.append(f'{lat_lng[0]} {lat_lng[1]}')
        cities.append(city)

# %%
print(len(cities))
print(len(new_lat_lng))
# Out:
# 7114
# 7114

# %%
print(cities)
# Out:
# ['ushuaia', 'punta arenas', 'mar del plata', 'tuatapere', 'souillac', 'rio gallegos', 'coihaique', 'saint-philippe', 'comodoro rivadavia', 'invercargill', 'balclutha', 'te anau', 'winton', 'clyde', 'waitati', 'castro', 'trelew', 'wanaka', 'fairlie', 'timaru', 'vaini', 'san carlos de bariloche', 'rawson', 'new norfolk', 'hobart', 'methven', 'christchurch', 'calbuco', 'puerto madryn', 'burnie', 'dobson', 'hanmer springs', 'puerto montt', 'neuquen', 'general roca', 'viedma', 'devonport', 'launceston', 'murchison', 'nelson', 'wellington', 'waipawa', 'osorno', 'rio bueno', 'takaka', 'tokomaru', 'takapau', 'valdivia', 'loncoche', 'villarrica', 'punta alta', 'morwell', 'sale', 'opunake', 'eltham', 'waiouru', 'hastings', 'wairoa', 'carahue', 'lautaro', 'vilcun', 'santa rosa', 'bahia blanca', 'tres arroyos', 'necochea', 'portland', 'warrnambool', 'colac', 'leopold', 'wonthaggi', 'waitara', 'otorohanga', 'reporoa', 'te karaka', 'tolaga bay', 'curanilahue', 'los angeles', 'mulchen', 'coihueco', 'olavarria', 'tandil', 'mount gambier', 'hamilton', 'ararat', 'ballarat', 'melton', 'healesville', 'traralgon', 'bairnsdale', 'lakes entrance', 'cooma', 'batemans bay', 'waiuku', 'kerepehi', 'maketu', 'bulnes', 'linares', 'san rafael', 'general pico', 'nueve de julio', 'azul', 'dolores', 'victor harbor', 'horsham', 'maryborough', 'bendigo', 'kyabram', 'wangaratta', 'albury', 'parakai', 'coromandel', 'constitucion', 'san clemente', 'molina', 'lincoln', 'veinticinco de mayo', 'san vicente', 'la plata', 'albany', 'port lincoln', 'murray bridge', 'swan hill', 'deniliquin', 'corowa', 'wagga wagga', 'tumut', 'queanbeyan', 'ulladulla', 'okaihau', 'ngunguru', 'santa cruz', 'machali', 'san luis', 'mercedes', 'venado tuerto', 'chacabuco', 'juan lacaze', 'santa lucia', 'minas', 'rocha', 'somerset west', 'hermanus', 'bredasdorp', 'george', 'plettenberg bay', 'kruisfontein', 'port elizabeth', 'busselton', 'collie', 'esperance', 'adelaide', 'gawler', 'mildura', 'griffith', 'leeton', 'cootamundra', 'young', 'goulburn', 'mittagong', 'wollongong', 'san antonio', 'santiago', 'lujan', 'rivadavia', 'rio cuarto', 'san nicolas', 'san pedro', 'durazno', 'treinta y tres', 'santa vitoria do palmar', 'atlantis', 'worcester', 'swellendam', 'oudtshoorn', 'willowmore', 'kirkwood', 'grahamstown', 'port alfred', 'flinders', 'whyalla', 'port pirie', 'forbes', 'cowra', 'orange', 'lithgow', 'sydney', 'la ligua', 'san felipe', 'mendoza', 'san martin', 'rio tercero', 'villa maria', 'bell ville', 'rosario', 'victoria', 'concepcion del uruguay', 'paso de los toros', 'tacuarembo', 'melo', 'rio branco', 'rio grande', 'saldanha', 'ceres', 'calvinia', 'graaff-reinet', 'somerset east', 'stutterheim', 'butterworth', 'mandurah', 'kwinana', 'northam', 'port augusta', 'broken hill', 'parkes', 'dubbo', 'mudgee', 'muswellbrook', 'kurri kurri', 'nelson bay', 'illapel', 'salamanca', 'san juan', 'villa carlos paz', 'cordoba', 'san francisco', 'rafaela', 'parana', 'concordia', 'salto', 'bage', 'pinheiro machado', 'cangucu', 'sao lourenco do sul', 'vredendal', 'carnarvon', 'de aar', 'middelburg', 'molteno', 'lady frere', 'umtata', 'umzimvubu', 'perth', 'gunnedah', 'tamworth', 'taree', 'port macquarie', 'ballina', 'ovalle', 'monte patria', 'vicuna', 'la rioja', 'santa fe', 'reconquista', 'bella union', 'artigas', 'santana do livramento', 'sao gabriel', 'cacapava do sul', 'encruzilhada do sul', 'tapes', 'palmares do sul', 'springbok', 'colesberg', 'aliwal north', 'quthing', 'kokstad', 'port shepstone', 'yulara', 'narrabri', 'armidale', 'nambucca heads', 'sawtell', 'la serena', 'catamarca', 'santiago del estero', 'uruguaiana', 'itaqui', 'sao francisco de assis', 'sao pedro do sul', 'julio de castilhos', 'santa cruz do sul', 'sao sebastiao do cai', 'sao francisco de paula', 'warmbad', 'upington', 'prieska', 'ritchie', 'bloemfontein', 'thaba nchu', 'maseru', 'thaba-tseka', 'mokhotlong', 'pietermaritzburg', 'stanger', 'geraldton', 'moree', 'inverell', 'grafton', 'vallenar', 'san lorenzo', 'sao borja', 'san ...

# %%
print(new_lat_lng)
# Out:
# ['-55.5 -70.5', '-54.5 -72.5', '-54.5 -37.5', '-54.5 158.5', '-53.5 73.5', '-52.5 -69.5', '-49.5 -75.5', '-49.5 68.5', '-48.5 -68.5', '-46.5 168.5', '-46.5 169.5', '-45.5 166.5', '-45.5 168.5', '-45.5 169.5', '-45.5 170.5', '-44.5 -74.5', '-44.5 -65.5', '-44.5 168.5', '-44.5 170.5', '-44.5 171.5', '-43.5 -176.5', '-43.5 -70.5', '-43.5 -64.5', '-43.5 146.5', '-43.5 147.5', '-43.5 171.5', '-43.5 172.5', '-42.5 -72.5', '-42.5 -65.5', '-42.5 145.5', '-42.5 171.5', '-42.5 172.5', '-41.5 -72.5', '-41.5 -68.5', '-41.5 -67.5', '-41.5 -63.5', '-41.5 146.5', '-41.5 147.5', '-41.5 172.5', '-41.5 173.5', '-41.5 174.5', '-41.5 175.5', '-40.5 -73.5', '-40.5 -72.5', '-40.5 172.5', '-40.5 175.5', '-40.5 176.5', '-39.5 -73.5', '-39.5 -72.5', '-39.5 -71.5', '-39.5 -62.5', '-39.5 146.5', '-39.5 147.5', '-39.5 173.5', '-39.5 174.5', '-39.5 175.5', '-39.5 176.5', '-39.5 177.5', '-38.5 -73.5', '-38.5 -72.5', '-38.5 -71.5', '-38.5 -64.5', '-38.5 -63.5', '-38.5 -60.5', '-38.5 -59.5', '-38.5 141.5', '-38.5 142.5', '-38.5 143.5', '-38.5 144.5', '-38.5 145.5', '-38.5 174.5', '-38.5 175.5', '-38.5 176.5', '-38.5 177.5', '-38.5 178.5', '-37.5 -73.5', '-37.5 -72.5', '-37.5 -71.5', '-37.5 -70.5', '-37.
 -62.5', '-31.5 -61.5', '-31.5 -60.5', '-31.5 -58.5', '-31.5 -57.5', '-31.5 -54.5', '-31.5 -53.5', '-31.5 -52.5', '-31.5 -51.5', '-31.5 18.5', '-31.5 21.5', '-31.5 23.5', '-31.5 24.5', '-31.5 26.5', '-31.5 27.5', '-31.5 28.5', '-31.5 29.5', '-31.5 115.5', '-31.5 149.5', '-31.5 151.5', '-31.5 152.5', '-31.5 153.5', '-31.5 159.5', '-30.5 -71.5', '-30.5 -70.5', '-30.5 -69.5', '-30.5 -67.5', '-30.5 -60.5', '-30.5 -59.5', '-30.5 -58.5', '-30.5 -56.5', '-30.5 -55.5', '-30.5 -54.5', '-30.5 -53.5', '-30.5 -52.5', '-30.5 -51.5', '-30.5 -50.5', '-30.5 17.5', '-30.5 25.5', '-30.5 26.5', '-30.5 27.5', '-30.5 29.5', '-30.5 30.5', '-30.5 127.5', '-30.5 148.5', ' ...

# %%
# create a dataframe to merge city names with original dataset
merger = pd.DataFrame({'coor1': new_lat_lng, 'city': cities})
merger
# Out:
#             coor1           city
# 0     -55.5 -70.5        ushuaia
# 1     -54.5 -72.5   punta arenas
# 2     -54.5 -37.5  mar del plata
# 3     -54.5 158.5      tuatapere
# 4      -53.5 73.5       souillac
# ...           ...            ...
# 7109    71.5 76.5         dikson
# 7110   72.5 -87.5        qaanaaq
# 7111   76.5 -68.5         narsaq
# 7112    76.5 16.5   longyearbyen
# 7113    77.5 14.5    barentsburg
#
# [7114 rows x 2 columns]

# %%
# merge 'merger' with 'data'
df_new = pd.merge(data, merger, on='coor1', how='inner')
df_new
# Out:
#          lat    lon        time     spi12        coor1           coor2  \
# 0      -55.5  -70.5  2012-01-16 -1.013668  -55.5 -70.5  [-55.5, -70.5]
# 1      -55.5  -70.5  2012-02-15 -1.142956  -55.5 -70.5  [-55.5, -70.5]
# 2      -55.5  -70.5  2012-03-16 -0.407607  -55.5 -70.5  [-55.5, -70.5]
# 3      -55.5  -70.5  2012-04-16 -0.726904  -55.5 -70.5  [-55.5, -70.5]
# 4      -55.5  -70.5  2012-05-16 -0.798656  -55.5 -70.5  [-55.5, -70.5]
# ...      ...    ...         ...       ...          ...             ...
# 85363   77.5   14.5  2012-08-16  0.100406    77.5 14.5    [77.5, 14.5]
# 85364   77.5   14.5  2012-09-16  0.102363    77.5 14.5    [77.5, 14.5]
# 85365   77.5   14.5  2012-10-16  0.088503    77.5 14.5    [77.5, 14.5]
# 85366   77.5   14.5  2012-11-16  0.064712    77.5 14.5    [77.5, 14.5]
# 85367   77.5   14.5  2012-12-16  0.043966    77.5 14.5    [77.5, 14.5]
#
#               city
# 0          ushuaia
# 1          ushuaia
# 2          ushuaia
# 3          ushuaia
# 4          ushuaia
# ...            ...
# 85363  barentsburg
# 85364  barentsburg
# 85365  barentsburg
# 85366  barentsburg
# 85367  barentsburg
#
# [85368 rows x 7 columns]

# %%
# export CSV to play with in tableau
df_new.to_csv('resources/cities.csv', header=True, index=False)
